# %% [markdown]
# ## Loading data

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import json
import pickle
import glob
import itertools
import pandas as pd
from utils.plot_util import *
import socket
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

print(tf.__version__)
# Out:
# 2.4.1

# %%
hostname = socket.gethostname()
if hostname == 'HAITI' or 'Gorleben':
    DIR = "C:/Users/xin/OneDrive - bwstaff/xin/trelleborg"
    DATASET = "D:/xin/datasets/Trelleborg/2021-01-27-V24/*/*.h5"
if hostname == 'BALI':
    DIR = "/home/xin/projects/trelleborg"
    DATASET = "/storage/xin/datasets/Trelleborg/2021-01-27-V24/*/*.h5"
if hostname == 'LAPTOP-1FOJITEG':
    DIR = "C:/Users/xinch/OneDrive - bwstaff/xin/trelleborg"
    DATASET = "C:/LINHC/VersucheDBs/Trelleborg/2021-01-27-V24/*/*.h5"
DIR = os.path.abspath(DIR)
DATASET = os.path.abspath(DATASET)

file_list = []
for file in glob.glob(DATASET):
    file_list.append(file)
file_list = sorted(file_list)
file_list_LEM1 = [file for file in file_list if 'LEM1' in file]
file_list_LEM1
# Out:
# ['D:\\xin\\datasets\\Trelleborg\\2021-01-27-V24\\2_Phase_A-D\\20210127_Phase_A-D_LEM1.h5',
#  'D:\\xin\\datasets\\Trelleborg\\2021-01-27-V24\\3_Phase_B-E\\20210201_3_Phase_B-E_LEM1.h5',
#  'D:\\xin\\datasets\\Trelleborg\\2021-01-27-V24\\4_Phase_C-F\\20210202_4_Phase_C-F_LEM1.h5',
#  'D:\\xin\\datasets\\Trelleborg\\2021-01-27-V24\\5_Phase_A-D\\20210218_5_Phase_A-D_LEM1.h5',
#  'D:\\xin\\datasets\\Trelleborg\\2021-01-27-V24\\7_Phase_C-F\\20210218_7_Phase_C-F_LEM1.h5',
#  'D:\\xin\\datasets\\Trelleborg\\2021-01-27-V24\\9_Phase_B-E\\9_Phase_B-E_LEM1.h5']

# %%
# check the last dataset
file = file_list_LEM1[1]
filename = file.split(os.sep)[-1][:-3]
pklName = DIR + '/data/shift_opts_freqs_all/' + filename + '.pkl'
shift_opts_freqs_all = pickle.load(open(pklName, 'rb')) 
h51 = h5py.File(file, "r")

print(filename)
print("ATTR:")
print(h51.attrs.keys())
print("Keys:")
print(h51.keys())
print("Points:")
print(h51['t'].shape)
print("shift_opts_freqs_all:")
print(shift_opts_freqs_all.shape)
# Out:
# 20210201_3_Phase_B-E_LEM1
# ATTR:
# <KeysViewHDF5 ['name_lookup', 'name_rev_lookup']>
# Keys:
# <KeysViewHDF5 ['S11_LEM1', 'S21_P1_LEM1', 'S21_P2_LEM1', 'S22_LEM1', 'hub1', 'hub2', 'ip1k1', 'ip1k2', 'ip2k1', 'ip2k2', 'k1at', 'k1f', 'k1p', 'k1t', 'k2at', 'k2f', 'k2p', 'k2t', 'phi', 'pos1', 'pos2', 'shub1', 'shub2', 'sk1at', 'sk1f', 'sk1p', 'sk1t', 'sk2at', 'sk2f', 'sk2p', 'sk2t', 'spd1', 'spd2', 'sphi', 'spos1', 'spos2', 'sspd1', 'sspd2', 'stdf', 't', 'tdf']>
# Points:
# (1069740,)
# shift_opts_freqs_all:
# (121, 1069740)

# %%
GT = ['pos1','spd1','ip1k1','k1t']
for gt in GT:
    plt.plot(h51[gt][:50000], label = gt)
plt.legend(bbox_to_anchor=(1.05, 1))

# %%
low = np.where(h51['spd1'][:]>-50)[0]
# skip the lsa in first 10000 points because some wierd patterns in speed, 
# check 'C:\\LINHC\\VersucheDBs\\Trelleborg\\2021-01-27-V24\\2_Phase_A-D\\20210127_Phase_A-D_LEM2.h5', 
if filename in ['20210127_Phase_A-D_LEM2']:
    low = low[low>10000]
pos_low = h51['pos1'][low]
low_sep = np.where(np.diff(low)>3000)[0] # check if 3000 fit for all datasets
pos_low_sep = np.split(pos_low,low_sep+1)
Ls = np.append(low[low_sep],low[-1])
Fs = np.append(low[0],low[low_sep+1])
if filename in ["20210218_7_Phase_C-F_LEM1","20210218_7_Phase_C-F_LEM2"]:
    Ls = Ls[:-1]
    Fs = Fs[:-1]

# %%
# # extract data from all datasets
# y4 = np.empty((0,4))
# pts_dataset = [0]
# for file in file_list_LEM1:
#     # filename = file.split('\\')[-1][:-3]
#     filename = file.split(os.sep)[-1][:-3]
#     pklName = DIR +'/data/shift_opts_freqs_all/' + filename + '.pkl'
#     shift_opts_freqs_all = pickle.load(open(pklName, 'rb')) 

#     with h5py.File(file, "r") as h51:
#         _y4 = []
#         N = 100 # ignore first N points
#         for gt in GT:
#             tmp = np.asarray(h51[gt][N:])
#             _y4.append(tmp)
#         _y4 = np.asarray(_y4).T
#         pts_dataset.append(_y4.shape[0])
#         print(filename)
#         print("_y4:")
#         print(_y4.shape)
#     y4 = np.vstack((y4,_y4))
# idx_dataset = np.cumsum(pts_dataset)
# print("Final Dataset:")
# print("y4:")
# print(y4.shape)
# print("index of each dataset:")
# print(idx_dataset)
# Out:
# 20210127_Phase_A-D_LEM1
# _y4:
# (987776, 4)
# 20210201_3_Phase_B-E_LEM1
# _y4:
# (1069640, 4)
# 20210202_4_Phase_C-F_LEM1
# _y4:
# (1088064, 4)
# 20210218_5_Phase_A-D_LEM1
# _y4:
# (1069443, 4)
# 20210218_7_Phase_C-F_LEM1
# _y4:
# (1050535, 4)
# 9_Phase_B-E_LEM1
# _y4:
# (1085674, 4)
# Final Dataset:
# y4:
# (6351132, 4)
# index of each dataset:
# [      0  987776 2057416 3145480 4214923 5265458 6351132]

# %%
# save
# pickle.dump( y4, open( DIR + "/data/training_data/y4.pkl", "wb" ))
# load
X = pickle.load( open( DIR + "/data/training_data/X.pkl", "rb" ) )
y4 = pickle.load( open( DIR + "/data/training_data/y4.pkl", "rb" ) )
idx_dataset = np.array('0 987776 2057416 3145480 4214923 5265458 6351132'.split()).astype(int)

# %%
h51.close()

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.model_selection import train_test_split

indices = np.arange(X.shape[0])
X_train, X_test, y_train, y_test, idx_train, idx_test = train_test_split(X, y4, indices, test_size=0.2, random_state=42)
idx_train_sort = np.sort(idx_train)
idx_test_sort = np.sort(idx_test)

# indices2 = np.arange(X_train.shape[0])
# X_train2, X_val, y_train2, y_val, idx_train2, idx_val = train_test_split(X_train, y_train, indices2, test_size=0.125, random_state=42) # 0.125 x 0.8 = 0.1

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (5080905, 242)
# (5080905, 4)
# (1270227, 242)

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)
# X_val_scaled = scaler.transform(X_val)
# scaler.mean_.shape

# %%
# train_dataset = tf.data.Dataset.from_tensor_slices((X_train_scaled, y_train))
# test_dataset = tf.data.Dataset.from_tensor_slices((X_test_scaled, y_test))
# val_dataset = tf.data.Dataset.from_tensor_slices((X_val_scaled, y_val))

# BATCH_SIZE = 64

# train_dataset = train_dataset.batch(BATCH_SIZE)
# test_dataset = test_dataset.batch(BATCH_SIZE)
# val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# ## Hyperparameter fine-tuning

# %%
def baseline_model():
  model = keras.Sequential([
      layers.Dense(128, input_dim=242, kernel_initializer='normal', activation='relu'),
      layers.Dense(64, kernel_initializer='normal',activation='relu'),
      layers.Dense(4,activation='linear')
  ])

  model.compile(loss='mean_squared_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# evaluate model
estimator = KerasRegressor(build_fn=baseline_model, epochs=100, batch_size=64, verbose=0)
kfold = KFold(n_splits=3)
results = cross_val_score(estimator, X_val_scaled, y_val, cv=kfold)
print("Baseline: %.2f (%.2f) MSE" % (abs(results.mean()), results.std()))
# Out:
# Baseline: 0.53 (0.13) MSE

# %% [markdown]
# ## Training

# %% [markdown]
# ### Baseline model with normalization

# %%
normalizer = preprocessing.Normalization()
normalizer.adapt(X_train)
# print(normalizer.mean.numpy())
# first = np.array(X[:1])
# with np.printoptions(precision=2, suppress=True):
#   print('First example:', first)
#   print()
#   print('Normalized:', normalizer(first).numpy())

# %%
def baseline_model_norm(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(128, input_dim=242, kernel_initializer='normal', activation='relu'),
      layers.Dense(64, kernel_initializer='normal',activation='relu'),
      layers.Dense(4,activation='linear')
  ])

  model.compile(loss='mean_squared_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
NN = baseline_model_norm(normalizer)
NN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization (Normalization (None, 242)               485
# _________________________________________________________________
# dense (Dense)                (None, 128)               31104
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 40,105
# Trainable params: 39,620
# Non-trainable params: 485
# _________________________________________________________________

# %%
# %%time
history = NN.fit(
    X_train, y_train, batch_size = 64,
    validation_split = 0.125,
    verbose=1, epochs=100)
# Out:
# Epoch 1/100
# 69466/69466 [==============================] - 166s 2ms/step - loss: 257.5983 - val_loss: 29.3836
# Epoch 2/100
# 69466/69466 [==============================] - 168s 2ms/step - loss: 22.2673 - val_loss: 22.7238
# Epoch 3/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 15.7496 - val_loss: 13.4106
# Epoch 4/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 13.1041 - val_loss: 10.6076
# Epoch 5/100
# 69466/69466 [==============================] - 158s 2ms/step - loss: 11.6357 - val_loss: 10.2496
# Epoch 6/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 10.4272 - val_loss: 9.6287
# Epoch 7/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 9.8058 - val_loss: 8.6181
# Epoch 8/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 9.1987 - val_loss: 8.6308
# Epoch 9/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 8.8104 - val_loss: 9.4740
# Epoch 10/100
# 69466/69466 [==============================] - 156s 2ms/step - loss: 8.4237 - val_loss: 8.1158
# Epoch 11/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 8.2007 - val_loss: 7.5742
# Epoch 12/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 7.9385 - val_loss: 7.7544
# Epoch 13/100
# 69466/69466 [==============================] - 156s 2ms/step - loss: 7.7390 - val_loss: 7.2829
# Epoch 14/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 7.5139 - val_loss: 7.7131
# Epoch 15/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 7.3196 - val_loss: 7.4067
# Epoch 16/100
# 69466/69466 [==============================] - 156s 2ms/step - loss: 7.2912 - val_loss: 7.3309
# Epoch 17/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 7.1001 - val_loss: 6.7632
# Epoch 18/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.9991 - val_loss: 6.8660
# Epoch 19/100
# 69466/69466 [==============================] - 156s 2ms/step - loss: 6.8716 - val_loss: 6.5543
# Epoch 20/100
# 69466/69466 [==============================] - 156s 2ms/step - loss: 6.7903 - val_loss: 7.0338
# Epoch 21/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.8093 - val_loss: 16.7492
# Epoch 22/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.6933 - val_loss: 6.5904
# Epoch 23/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.5085 - val_loss: 7.6868
# Epoch 24/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.5078 - val_loss: 7.1383
# Epoch 25/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.4477 - val_loss: 6.2760
# Epoch 26/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.3171 - val_loss: 6.0963
# Epoch 27/100
# 69466/69466 [==============================] - 156s 2ms/step - loss: 6.2881 - val_loss: 7.5005
# Epoch 28/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.2680 - val_loss: 6.1729
# Epoch 29/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.2514 - val_loss: 6.1129
# Epoch 30/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.1352 - val_loss: 6.3538
# Epoch 31/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.0861 - val_loss: 6.0541
# Epoch 32/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.0934 - val_loss: 6.1085
# Epoch 33/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 6.0560 - val_loss: 5.8458
# Epoch 34/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.9835 - val_loss: 6.3418
# Epoch 35/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.9090 - val_loss: 5.7210
# Epoch 36/100
# 69466/69466 [==============================] - 158s 2ms/step - loss: 5.9452 - val_loss: 5.9952
# Epoch 37/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.8965 - val_loss: 6.9874
# Epoch 38/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.8786 - val_loss: 7.2922
# Epoch 39/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.8429 - val_loss: 6.1929
# Epoch 40/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.8035 - val_loss: 5.7546
# Epoch 41/100
# 69466/69466 [==============================] - 158s 2ms/step - loss: 5.7519 - val_loss: 5.8898
# Epoch 42/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.7168 - val_loss: 5.8674
# Epoch 43/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.6948 - val_loss: 5.9894
# Epoch 44/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.7064 - val_loss: 5.7624
# Epoch 45/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.6468 - val_loss: 5.5471
# Epoch 46/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.6574 - val_loss: 5.6385
# Epoch 47/100
# 69466/69466 [==============================] - 158s 2ms/step - loss: 5.5771 - val_loss: 5.6274
# Epoch 48/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.5778 - val_loss: 5.7983
# Epoch 49/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.5645 - val_loss: 5.9222
# Epoch 50/100
# 69466/69466 [==============================] - 158s 2ms/step - loss: 5.5511 - val_loss: 5.5350
# Epoch 51/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.5075 - val_loss: 5.7964
# Epoch 52/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.5155 - val_loss: 5.7296
# Epoch 53/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.4667 - val_loss: 5.6674
# Epoch 54/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.4448 - val_loss: 7.3161
# Epoch 55/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.4568 - val_loss: 5.8821
# Epoch 56/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.4232 - val_loss: 5.5774
# Epoch 57/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.4091 - val_loss: 5.6133
# Epoch 58/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.4237 - val_loss: 5.6323
# Epoch 59/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.3812 - val_loss: 5.3586
# Epoch 60/100
# 69466/69466 [==============================] - 156s 2ms/step - loss: 5.3567 - val_loss: 5.2336
# Epoch 61/100
# 69466/69466 [==============================] - 156s 2ms/step - loss: 5.3872 - val_loss: 5.5550
# Epoch 62/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.3561 - val_loss: 5.4880
# Epoch 63/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.3397 - val_loss: 5.6777
# Epoch 64/100
# 69466/69466 [==============================] - 156s 2ms/step - loss: 5.3128 - val_loss: 5.4698
# Epoch 65/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.2904 - val_loss: 5.6013
# Epoch 66/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.2667 - val_loss: 5.2040
# Epoch 67/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.2862 - val_loss: 5.5379
# Epoch 68/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.2303 - val_loss: 5.4906
# Epoch 69/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.2344 - val_loss: 5.2578
# Epoch 70/100
# 69466/69466 [==============================] - 157s 2ms/step - loss: 5.2468 - val_loss: 5.5602
# Epoch 71/100
# 69466/69466 [==============================] - 164s 2ms/step - loss: 5.2061 - val_loss: 5.4084
# Epoch 72/100
# 69466/69466 [==============================] - 162s 2ms/step - loss: 5.2043 - val_loss: 5.2870
# Epoch 73/100
# 69466/69466 [==============================] - 162s 2ms/step - loss: 5.2067 - val_loss: 5.1629
# Epoch 74/100
# 69466/69466 [==============================] - 162s 2ms/step - loss: 5.1915 - val_loss: 5.8650
# Epoch 75/100
# 69466/69466 [==============================] - 162s 2ms/step - loss: 5.1924 - val_loss: 5.6743
# Epoch 76/100
# 69466/69466 [==============================] - 161s 2ms/step - loss: 5.1688 - val_loss: 5.5498
# Epoch 77/100
# 69466/69466 [==============================] - 161s 2ms/step - loss: 5.1290 - val_loss: 5.3083
# Epoch 78/100
# 69466/69466 [==============================] - 161s 2ms/step - loss: 5.1574 - val_loss: 5.1771
# Epoch 79/100
# 69466/69466 [==============================] - 161s 2ms/step - loss: 5.1213 - val_loss: 5.5345
# Epoch 80/100
# 69466/69466 [==============================] - 161s 2ms/step - loss: 5.1523 - val_loss: 5.4005
# Epoch 81/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.1647 - val_loss: 5.7417
# Epoch 82/100
# 69466/69466 [==============================] - 161s 2ms/step - loss: 5.1205 - val_loss: 5.4406
# Epoch 83/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.1093 - val_loss: 5.2763
# Epoch 84/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0850 - val_loss: 5.7398
# Epoch 85/100
# 69466/69466 [==============================] - 161s 2ms/step - loss: 5.0659 - val_loss: 5.0549
# Epoch 86/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0691 - val_loss: 5.6220
# Epoch 87/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0765 - val_loss: 5.1570
# Epoch 88/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0503 - val_loss: 5.2298
# Epoch 89/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0549 - val_loss: 5.6372
# Epoch 90/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0779 - val_loss: 5.0583
# Epoch 91/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0226 - val_loss: 5.3898
# Epoch 92/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0097 - val_loss: 5.3221
# Epoch 93/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0035 - val_loss: 5.7765
# Epoch 94/100
# 69466/69466 [==============================] - 161s 2ms/step - loss: 4.9876 - val_loss: 5.3496
# Epoch 95/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0164 - val_loss: 5.0750
# Epoch 96/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 4.9761 - val_loss: 4.9258
# Epoch 97/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 5.0031 - val_loss: 5.3747
# Epoch 98/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 4.9574 - val_loss: 5.2898
# Epoch 99/100
# 69466/69466 [==============================] - 159s 2ms/step - loss: 4.9666 - val_loss: 5.6124
# Epoch 100/100
# 69466/69466 [==============================] - 160s 2ms/step - loss: 4.9782 - val_loss: 5.1869
# Wall time: 4h 23min 42s

# %%
plot_loss(history)

# %%
NN.save(DIR + "/models/NN_norm_combi_all")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\xin\OneDrive - bwstaff\xin\trelleborg/models/NN_norm_combi_all\assets

# %%
NN = tf.keras.models.load_model(DIR + "/models/NN_norm_combi_all")

# %%
# evaluation on both training and test sets

# X_ = scaler.fit_transform(X)
y_ = NN.predict(X)
y_train_ = y_[idx_train_sort].squeeze()
y_test_ =y_[idx_test_sort].squeeze()

# %%
err_dict = {
    'Output':GT,
    'MSE of predictions on training set' : np.mean(np.square(y4[idx_train_sort] - y_train_), axis=0),
    'MSE of predictions on test set' : np.mean(np.square(y4[idx_test_sort] - y_test_), axis=0)
}
df = pd.DataFrame.from_dict(err_dict)
df
# Out:
#   Output  MSE of predictions on training set  MSE of predictions on test set
# 0   pos1                            4.964193                        5.042924
# 1   spd1                            6.528190                        6.929112
# 2  ip1k1                            3.812937                        4.386734
# 3    k1t                            4.326115                        4.364742

# %%
print("Evaluations on lsa of the last dataset")
idx_com_train = np.intersect1d(idx_train_sort, low)
idx_com_test = np.intersect1d(idx_test_sort, low)
y_train_lsa_ = y_[idx_com_train]
y_test_lsa_ = y_[idx_com_test]
err_dict_lsa = {
    'Output':GT,
    'MSE of predictions on training set and lsa' : np.mean(np.square(y4[idx_com_train] - y_train_lsa_), axis=0),
    'MSE of predictions on test set and lsa' : np.mean(np.square(y4[idx_com_test] - y_test_lsa_), axis=0)
}
df_lsa = pd.DataFrame.from_dict(err_dict_lsa)
df_lsa
# Out:
# Evaluations on lsa
#   Output  MSE of predictions on training set and lsa  \
# 0   pos1                                    2.456223
# 1   spd1                                    5.169525
# 2  ip1k1                                    1.947043
# 3    k1t                                    4.172841
#
#    MSE of predictions on test set and lsa
# 0                                2.483515
# 1                                5.403413
# 2                                2.057227
# 3                                4.224470

# %%
from sklearn.metrics import mean_squared_error
print ("MSE of the prediction on training set: ", mean_squared_error(y_train_,y4[idx_train_sort]))
print ("MSE of the prediction on test set: ", mean_squared_error(y_test_,y4[idx_test_sort]))
# Out:
# MSE of the prediction on training set:  4.9078586659893615
# MSE of the prediction on test set:  5.180877957058089

# %%
#   predictioin vs ground truth in one plot
#   for multiple outputs (with names listed in the argument "outputs") in one plot
#   with only first 50000 points"""
# %matplotlib inline
plot_gt_pre_overlap_mul(y4,y_,GT)

# %%
# (predictioin for X_test and X_train separately) vs (ground truth)  
# for multiple outputs (with names listed in the argument "outputs") in one plot
# %matplotlib inline
plot_gt_pre_sep_mul(y4,idx_train_sort,y_train_,idx_test_sort,y_test_,GT)

# %% [markdown]
# ### An alternative way to split the dataset: leave one out

# %%
i = idx_dataset[-2]
X_train = X[:i]
X_test = X[i:]
y_train = y4[:i]
y_test = y4[i:]
idx_train_sort = np.arange(i)
idx_test_sort = np.arange(i,y4.shape[0])

print(X_train.shape)
print(X_test.shape)
# Out:
# (5265458, 242)
# (1085674, 242)

# %%
def baseline_model_norm(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(128, input_dim=242, kernel_initializer='normal', activation='relu'),
      layers.Dense(64, kernel_initializer='normal',activation='relu'),
      layers.Dense(4)
  ])

  model.compile(loss='mean_squared_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

normalizer = preprocessing.Normalization()
normalizer.adapt(X_train)
NN = baseline_model_norm(normalizer)
NN.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_4 (Normalizati (None, 242)               485
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               31104
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_16 (Dense)             (None, 4)                 260
# =================================================================
# Total params: 40,105
# Trainable params: 39,620
# Non-trainable params: 485
# _________________________________________________________________

# %%
# %%time
history = NN.fit(
    X_train, y_train, batch_size = 64,
    validation_split=0.2,
    verbose=1, epochs=100)
# Out:
# Epoch 1/100
# 65819/65819 [==============================] - 179s 3ms/step - loss: 241.2355 - val_loss: 394.4056
# Epoch 2/100
# 65819/65819 [==============================] - 173s 3ms/step - loss: 17.2998 - val_loss: 362.3746
# Epoch 3/100
# 65819/65819 [==============================] - 170s 3ms/step - loss: 12.1925 - val_loss: 407.7020
# Epoch 4/100
# 65819/65819 [==============================] - 171s 3ms/step - loss: 10.0685 - val_loss: 406.8488
# Epoch 5/100
# 65819/65819 [==============================] - 164s 2ms/step - loss: 8.8846 - val_loss: 412.9415
# Epoch 6/100
# 65819/65819 [==============================] - 168s 3ms/step - loss: 8.0747 - val_loss: 398.6315
# Epoch 7/100
# 65819/65819 [==============================] - 169s 3ms/step - loss: 7.5968 - val_loss: 411.5872
# Epoch 8/100
# 65819/65819 [==============================] - 173s 3ms/step - loss: 7.1075 - val_loss: 415.4759
# Epoch 9/100
# 65819/65819 [==============================] - 169s 3ms/step - loss: 6.7906 - val_loss: 423.9539
# Epoch 10/100
# 65819/65819 [==============================] - 167s 3ms/step - loss: 6.5108 - val_loss: 433.4985
# Epoch 11/100
# 65819/65819 [==============================] - 172s 3ms/step - loss: 6.2979 - val_loss: 398.6774
# Epoch 12/100
# 65819/65819 [==============================] - 169s 3ms/step - loss:
100
# 65819/65819 [==============================] - 178s 3ms/step - loss: 3.8173 - val_loss: 422.0388
# Epoch 89/100
# 65819/65819 [==============================] - 178s 3ms/step - loss: 3.8238 - val_loss: 433.4680
# Epoch 90/100
# 65819/65819 [==============================] - 178s 3ms/step - loss: 3.7928 - val_loss: 428.4241
# Epoch 91/100
# 65819/65819 [==============================] - 178s 3ms/step - loss: 3.7915 - val_loss: 433.5459
# Epoch 92/100
# 65819/65819 [==============================] - 178s 3ms/step - loss: 3.7922 - val_loss: 441.3262
# Epoch 93/100
# 65819/65819 [==============================] - 177s 3ms/step - loss: 3.7729 - val_loss: 431.9693
# Epoch 94/100
# 65819/65819 [==============================] - 168s 3ms/step - loss: 3.7885 - val_loss: 428.2634
# Epoch 95/100
# 65819/65819 [==============================] - 174s 3ms/step - loss: 3.7597 - val_loss: 427.0488
# Epoch 96/100
# 65819/65819 [==============================] - 170s 3ms/step - loss: 3.7804 - val_loss: 444.5357
# Epoch 97/100
# 65819/65819 [==============================] - 173s 3ms/step - loss: 3.7808 - val_loss: 440.5614
# Epoch 98/100
# 65819/65819 [==============================] - 172s 3ms/step - loss: 3.7718 - val_loss: 469.1877
# Epoch 99/100
# 65819/65819 [==============================] - 165s 3ms/step - loss: 3.7345 - val_loss: 426.7127
# Epoch 100/100
# 65819/65819 [==============================] - 169s 3ms/step - loss: 3.7463 - val_loss: 434.0459
# Wall time: 4h 48min 7s

# %%
plot_loss(history)

# %%
NN.save(DIR + "/models/NN_norm_combi_all_loo")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\xin\OneDrive - bwstaff\xin\trelleborg/models/NN_norm_combi_all_loo\assets

# %%
NN = keras.models.load_model(DIR + "/models/NN_norm_combi_all_loo")

# %%
# evaluation on both training and test sets

# X_ = scaler.fit_transform(X)
y_ = NN.predict(X)
y_train_ = y_[idx_train_sort].squeeze()
y_test_ =y_[idx_test_sort].squeeze()

# %%
err_dict = {
    'Output':GT,
    'MSE of predictions on training set' : np.mean(np.square(y4[idx_train_sort] - y_train_), axis=0),
    'MSE of predictions on test set' : np.mean(np.square(y4[idx_test_sort] - y_test_), axis=0)
}
df = pd.DataFrame.from_dict(err_dict)
df
# Out:
#   Output  MSE of predictions on training set  MSE of predictions on test set
# 0   pos1                           51.006040                      185.132548
# 1   spd1                          171.347753                     1016.058509
# 2  ip1k1                           86.390010                      357.022689
# 3    k1t                           50.398051                       75.895314

# %%
print("Evaluations on lsa of the last dataset")

idx_com_test = np.intersect1d(idx_test_sort, low+idx_dataset[-2])

y_test_lsa_ = y_[idx_com_test]
err_dict_lsa = {
    'Output':GT,
    'MSE of predictions on test set and lsa' : np.mean(np.square(y4[idx_com_test] - y_test_lsa_), axis=0)
}
df_lsa = pd.DataFrame.from_dict(err_dict_lsa)
df_lsa
# Out:
# Evaluations on lsa of the last dataset
#   Output  MSE of predictions on test set and lsa
# 0   pos1                               14.121962
# 1   spd1                             2506.555739
# 2  ip1k1                               19.659860
# 3    k1t                               27.866292

# %%
from sklearn.metrics import mean_squared_error
print ("MSE of the prediction on training set: ", mean_squared_error(y_train_,y4[idx_train_sort]))
print ("MSE of the prediction on test set: ", mean_squared_error(y_test_,y4[idx_test_sort]))
# Out:
# MSE of the prediction on training set:  89.78546354417857
# MSE of the prediction on test set:  408.52726524796026

# %%
#   predictioin vs ground truth in one plot
#   for multiple outputs (with names listed in the argument "outputs") in one plot
#   with only first 50000 points"""
print("Those are the results on training set:")
# %matplotlib inline
plot_gt_pre_overlap_mul(y4,y_,GT)
# Out:
# Those are the results on training set:

# %%
# (predictioin for X_test and X_train separately) vs (ground truth)  
# for multiple outputs (with names listed in the argument "outputs") in one plot
# %matplotlib inline
plot_gt_pre_sep_mul(y4,idx_train_sort,y_train_,idx_test_sort,y_test_,GT)

# %% [markdown]
# #### bigger_model

# %%
def model_4(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(256, input_dim=242, kernel_initializer='normal', activation='relu'),
      layers.Dense(128, kernel_initializer='normal', activation='relu'),
      layers.Dense(64, kernel_initializer='normal',activation='relu'),
      layers.Dense(32, kernel_initializer='normal',activation='relu'),
      layers.Dense(4)
  ])

  model.compile(loss='mean_squared_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

normalizer = preprocessing.Normalization()
normalizer.adapt(X_train)
NN = model_4(normalizer)
NN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_1 (Normalizati (None, 242)               485
# _________________________________________________________________
# dense (Dense)                (None, 256)               62208
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 106,057
# Trainable params: 105,572
# Non-trainable params: 485
# _________________________________________________________________

# %%
# %%time
history = NN.fit(
    X_train, y_train, batch_size = 64,
    validation_split=0.2,
    verbose=1, epochs=100)
# Out:
# Epoch 1/100
# 65819/65819 [==============================] - 228s 3ms/step - loss: 179.3071 - val_loss: 497.4250
# Epoch 2/100
# 65819/65819 [==============================] - 204s 3ms/step - loss: 16.6355 - val_loss: 393.0887
# Epoch 3/100
# 65819/65819 [==============================] - 209s 3ms/step - loss: 11.4866 - val_loss: 506.4928
# Epoch 4/100
# 65819/65819 [==============================] - 207s 3ms/step - loss: 9.5548 - val_loss: 579.1453
# Epoch 5/100
# 65819/65819 [==============================] - 208s 3ms/step - loss: 8.3196 - val_loss: 442.2370
# Epoch 6/100
# 65819/65819 [==============================] - 213s 3ms/step - loss: 7.8578 - val_loss: 502.8495
# Epoch 7/100
# 65819/65819 [==============================] - 208s 3ms/step - loss: 6.9657 - val_loss: 474.0186
# Epoch 8/100
# 65819/65819 [==============================] - 211s 3ms/step - loss: 6.5368 - val_loss: 448.8397
# Epoch 9/100
# 65819/65819 [==============================] - 210s 3ms/step - loss: 5.9747 - val_loss: 503.0805
# Epoch 10/100
# 65819/65819 [==============================] - 209s 3ms/step - loss: 5.8713 - val_loss: 652.8555
# Epoch 11/100
# 65819/65819 [==============================] - 210s 3ms/step - loss: 5.6513 - val_loss: 620.3032
# Epoch 12/100
# 65819/65819 [==============================] - 208s 3ms/step - loss: 5.4403 - val_loss: 600.5500
# Epoch 13/100
# 65819/65819 [==============================] - 211s 3ms/step - loss: 5.2274 - val_loss: 492.1696
# Epoch 14/100
# 65819/65819 [==============================] - 207s 3ms/step - loss: 5.1119 - val_loss: 610.9356
# Epoch 15/100
# 65819/65819 [==============================] - 207s 3ms/step - loss: 4.9650 - val_loss: 429.5414
# Epoch 16/100
# 65819/65819 [==============================] - 204s 3ms/step - loss: 4.8572 - val_loss: 569.3804
# Epoch 17/100
# 65819/65819 [==============================] - 230s 3ms/step - loss: 4.6393 - val_loss: 554.5879
# Epoch 18/100
# 65819/65819 [==============================] - 227s 3ms/step - loss: 4.6322 - val_loss: 538.5168
# Epoch 19/100
# 65819/65819 [==============================] - 223s 3ms/step - loss: 4.5015 - val_loss: 634.3898
# Epoch 20/100
# 65819/65819 [==============================] - 223s 3ms/step - loss: 4.4779 - val_loss: 608.6992
# Epoch 21/100
# 65819/65819 [==============================] - 224s 3ms/step - loss: 4.3979 - val_loss: 532.0486
# Epoch 22/100
# 65819/65819 [==============================] - 224s 3ms/step - loss: 4.3265 - val_loss: 568.3232
# Epoch 23/100
# 65819/65819 [==============================] - 224s 3ms/step - loss: 4.3113 - val_loss: 497.0587
# Epoch 24/100
# 65819/65819 [==============================] - 224s 3ms/step - loss: 4.1730 - val_loss: 516.9029
# Epoch 25/100
# 65819/65819 [==============================] - 208s 3ms/step - loss:
# Epoch 95/100
# 65819/65819 [==============================] - 228s 3ms/step - loss: 2.8223 - val_loss: 459.0460
# Epoch 96/100
# 65819/65819 [==============================] - 223s 3ms/step - loss: 2.8226 - val_loss: 431.5881
# Epoch 97/100
# 65819/65819 [==============================] - 222s 3ms/step - loss: 2.7843 - val_loss: 528.9212
# Epoch 98/100
# 65819/65819 [==============================] - 226s 3ms/step - loss: 2.8523 - val_loss: 515.9381
# Epoch 99/100
# 65819/65819 [==============================] - 221s 3ms/step - loss: 2.7542 - val_loss: 472.0953
# Epoch 100/100
# 65819/65819 [==============================] - 222s 3ms/step - loss: 2.7844 - val_loss: 520.0869
# Wall time: 5h 56min 36s

# %%
plot_loss(history)

# %%
NN.save(DIR + "/models/NN_norm_combi_all_loo_4")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\xin\OneDrive - bwstaff\xin\trelleborg/models/NN_norm_combi_all_loo_4\assets

# %%
NN= keras.models.load_model(DIR + "/models/NN_norm_combi_all_loo_4")

# %%
# evaluation on both training and test sets

# X_ = scaler.fit_transform(X)
y_ = NN.predict(X)
y_train_ = y_[idx_train_sort].squeeze()
y_test_ =y_[idx_test_sort].squeeze()

# %%
err_dict = {
    'Output':GT,
    'MSE of predictions on training set' : np.mean(np.square(y4[idx_train_sort] - y_train_), axis=0),
    'MSE of predictions on test set' : np.mean(np.square(y4[idx_test_sort] - y_test_), axis=0)
}
df = pd.DataFrame.from_dict(err_dict)
df
# Out:
#   Output  MSE of predictions on training set  MSE of predictions on test set
# 0   pos1                           34.470759                      162.528106
# 1   spd1                          301.621622                     1245.895814
# 2  ip1k1                           59.195279                      235.998705
# 3    k1t                           31.126116                       67.184585

# %%
print("Evaluations on lsa of the last dataset")

idx_com_test = np.intersect1d(idx_test_sort, low+ idx_dataset[-2])

y_test_lsa_ = y_[idx_com_test]
err_dict_lsa = {
    'Output':GT,
    'MSE of predictions on test set and lsa' : np.mean(np.square(y4[idx_com_test] - y_test_lsa_), axis=0)
}
df_lsa = pd.DataFrame.from_dict(err_dict_lsa)
df_lsa
# Out:
# Evaluations on lsa of the last dataset
#   Output  MSE of predictions on test set and lsa
# 0   pos1                               17.599729
# 1   spd1                             2395.225989
# 2  ip1k1                               11.990175
# 3    k1t                               35.813573

# %%
from sklearn.metrics import mean_squared_error
print ("MSE of the prediction on training set: ", mean_squared_error(y_train_,y4[idx_train_sort]))
print ("MSE of the prediction on test set: ", mean_squared_error(y_test_,y4[idx_test_sort]))
# Out:
# MSE of the prediction on training set:  106.60344400794625
# MSE of the prediction on test set:  427.90180244984384

# %%
#   predictioin vs ground truth in one plot
#   for multiple outputs (with names listed in the argument "outputs") in one plot
#   with only first 50000 points"""
# %matplotlib inline
plot_gt_pre_overlap_mul(y4,y_,GT)

# %%
# (predictioin for X_test and X_train separately) vs (ground truth)  
# for multiple outputs (with names listed in the argument "outputs") in one plot
# %matplotlib inline
plot_gt_pre_sep_mul(y4,idx_train_sort,y_train_,idx_test_sort,y_test_,GT)
